# %%
import fastf1 as ff1
from fastf1 import plotting
from fastf1 import utils
import fastf1.legacy

import numpy as np

from matplotlib import pyplot as plt
from matplotlib.collections import LineCollection
from matplotlib import cm
import matplotlib.font_manager as fm

import pandas as pd

import seaborn as sns

# %%
ff1.Cache.enable_cache('Cache')

# %%
plotting.setup_mpl()

# %%
year = 2023
gp = 'Brazil'
event = 'R'

# %%
session = ff1.get_session(year, gp, event)

# %%
session.load()
# Out:
# core           INFO 	Loading data for São Paulo Grand Prix - Race [v2.3.0]
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# c:\Users\larsl\AppData\Local\Programs\Python\Python311\Lib\site-packages\fastf1\core.py:1492: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for key, value in row.iteritems():
# c:\Users\larsl\AppData\Local\Programs\Python\Python311\Lib\site-packages\fastf1\core.py:1492: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for key, value in row.iteritems():
# ...

# %%
t5_finishers = session.drivers[:5]

t5_finishers
# Out:
# ['1', '4', '14', '11', '18']

# %%
driver_laps = session.laps.pick_drivers(t5_finishers).pick_quicklaps()
driver_laps = driver_laps.reset_index()

driver_laps
# Out:
#      index                   Time DriverNumber                LapTime  \
# 0        4 0 days 01:35:39.894000            1 0 days 00:01:15.745000
# 1        5 0 days 01:36:55.441000            1 0 days 00:01:15.547000
# 2        6 0 days 01:38:11.032000            1 0 days 00:01:15.591000
# 3        7 0 days 01:39:26.896000            1 0 days 00:01:15.864000
# 4        8 0 days 01:40:43.065000            1 0 days 00:01:16.169000
# ..     ...                    ...          ...                    ...
# 310    350 0 days 02:54:54.836000           18 0 days 00:01:14.007000
# 311    351 0 days 02:56:09.232000           18 0 days 00:01:14.396000
# 312    352 0 days 02:57:23.570000           18 0 days 00:01:14.338000
# 313    353 0 days 02:58:38.078000           18 0 days 00:01:14.508000
# 314    354 0 days 02:59:52.835000           18 0 days 00:01:14.757000
#
#      LapNumber PitOutTime PitInTime            Sector1Time  \
# 0          5.0        NaT       NaT 0 days 00:00:19.651000
# ...

# %%
finishing_order = [session.get_driver(i)['Abbreviation'] for i in t5_finishers]

finishing_order
# Out:
# ['VER', 'NOR', 'ALO', 'PER', 'STR']

# %%
driver_colors = {abv: ff1.plotting.DRIVER_COLORS[driver] for abv,
                driver in ff1.plotting.DRIVER_TRANSLATE.items()}

driver_colors
# Out:
# {'LEC': '#dc0000',
#  'SAI': '#ff8181',
#  'VER': '#0600ef',
#  'PER': '#716de2',
#  'RIC': '#ff8700',
#  'NOR': '#eeb370',
#  'ALO': '#0090ff',
#  'OCO': '#70c2ff',
#  'BOT': '#900000',
#  'ZHO': '#500000',
#  'GAS': '#2b4562',
#  'TSU': '#356cac',
#  'MAG': '#ffffff',
#  'MSC': '#cacaca',
#  'VET': '#006f62',
#  'HUL': '#2f9b90',
#  'STR': '#25a617',
#  'HAM': '#00d2be',
#  'RUS': '#24ffff',
#  'ALB': '#005aff',
#  'LAT': '#012564'}

# %%
fig, ax = plt.subplots(figsize=(22, 8))

title = f'{str(event)} - Top 5 finishers race pace distribution {str(year)} {str(gp)} Grand Prix'
plt.suptitle(title)

driver_laps['LapTime (s)'] = driver_laps['LapTime'].dt.total_seconds()

plt.ylim(72, 78.5)

sns.violinplot(data=driver_laps,
              x='Driver',
              y='LapTime (s)',
              inner=None,
              density_norm='area',
              order=finishing_order,
              palette=driver_colors,
              hue='Driver',
              legend=False)

fig.savefig(f'Figures/{title}.png')

plt.show()
